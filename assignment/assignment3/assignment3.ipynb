# %% [markdown]
# # Survival Analysis

# %%
from survival import data1, data2, SurvivalTable, AdvancedSurvivalAnalysis

# %% [markdown]
# ## Part 1

# %%
survival_table = SurvivalTable(data1)
survival_table.build_table()
survival_table.print_table()
survival_table.plot_survival_curve()
survival_table.median_survival_time()
# Out:
# Classes successfully imported.
#        N  D  S Probability of dying Probability of living
# Time
# 1     10  6  4         4 / 10 = 0.4          6 / 10 = 0.6
# 4     10  5  4         4 / 10 = 0.4          5 / 10 = 0.5
# 5      9  4  4         4 / 9 = 0.44          4 / 9 = 0.44
# 7      8  3  3         3 / 8 = 0.38          3 / 8 = 0.38
# 10     6  2  3          3 / 6 = 0.5          2 / 6 = 0.33
# 12     5  2  1          1 / 5 = 0.2           2 / 5 = 0.4
# 14     3  1  1         1 / 3 = 0.33          1 / 3 = 0.33
# 16     2  0  1          1 / 2 = 0.5           0 / 2 = 0.0
# 12.0

# %% [markdown]
# ## Part 2

# %%
advanced_survival = AdvancedSurvivalAnalysis(data2)
advanced_survival.plot_survival_curves()
advanced_survival.test_global_effect()
advanced_survival.test_pairwise_effects()
# Out:
# Classes successfully imported.
# Log-Rank Test
# p-value: 1.6240630634437227e-62
# There is a significant difference between at least one pair of survival curves.
#
# Multiple Pairwise Comparisons with Bonferroni Correction
# ...
# Group 1 vs Group 2: p-value = 0.0000, test statistic = 26.08
# Group 1 vs Group 3: p-value = 0.3691, test statistic = 0.81
# Group 2 vs Group 3: p-value = 0.0001, test statistic = 16.07
# Group 1 and Group 2 have significantly different survival curves. Corrected p-value: 0.0000
# Group 2 and Group 3 have significantly different survival curves. Corrected p-value: 0.0002
